# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')

# %%
x_train = np.array([1.0,2.0]) # in sq ft 1000 
y_train = np.array([300.0, 500.0])# in 1000's of dollars
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
print(f"x_train_shape= {x_train.shape}")
m=x_train.shape[0]
print(f"Number of training examples is: {m}")
# Out:
# x_train_shape= (2,)
# Number of training examples is: 2

# %%
m=len(x_train)
print(f"Number of training examples is: {m}")
# Out:
# Number of training examples is: 2

# %%
i=0
x_i = x_train[i];
y_i = y_train[i];
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")

i=1
x_i = x_train[i];
y_i = y_train[i];
print(f"(x^({i}), y^({i})) = ({x_i}, {y_i})")
# Out:
# (x^(0), y^(0)) = (1.0, 300.0)
# (x^(1), y^(1)) = (2.0, 500.0)

# %%
plt.scatter(x_train, y_train, marker='x', c='r')
plt.title("Housing prices")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
w = 200
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 200
# b: 100

# %%
def compute_model_output(x, w, b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w*x[i] + b
    return f_wb

# %%
temp_fwb = compute_model_output(x_train, w, b)
plt.plot(x_train, temp_fwb, c='b',label='Our Prediction')
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')
plt.title("Housing Prices")
plt.ylabel('Price (in 1000s of dollars)')
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
x=1.2
y_hat = w*x +b
print(f"predicted values in 1000s of dollar {y_hat}")
# Out:
# predicted values in 1000s of dollar 340.0
